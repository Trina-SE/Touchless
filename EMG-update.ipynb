# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
Input_path = 'EMG-data/EMG-data.csv'
df = pd.read_csv(Input_path)
print(df.head())
print(df.shape)
# Out:
#    time  channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0     1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 1     5   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 2     6  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 3     7  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 4     8  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
#
#    channel8  class  label
# 0  -0.00001      0      1
# 1  -0.00001      0      1
# 2   0.00001      0      1
# 3   0.00001      0      1
# 4   0.00001      0      1
# (4237907, 11)

# %%
print("class :", df["class"].unique())
print()
#print("Labels :",df["label"].unique()) # 36 people hand gesture data
#print()
print("Value Count :\n",df["class"].value_counts())
# Out:
# class : [0 1 2 3 4 5 6 7]
#
# Value Count :
#  0    2725157
# 6     253009
# 5     251733
# 4     251570
# 1     250055
# 3     249494
# 2     243193
# 7      13696
# Name: class, dtype: int64

# %%
features = df.drop(columns=["label","class","time"])
display(features.head())
#print(features.shape())
# Out:
#    channel1  channel2  channel3  channel4  channel5  channel6  channel7  \
# 0   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 1   0.00001  -0.00002  -0.00001  -0.00003   0.00000  -0.00001   0.00000
# 2  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 3  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
# 4  -0.00001   0.00001   0.00002   0.00000   0.00001  -0.00002  -0.00001
#
#    channel8
# 0  -0.00001
# 1  -0.00001
# 2   0.00001
# 3   0.00001
# 4   0.00001

# %%
Class = df["class"]
print(Class.unique())
#print(Class.shape())
# Out:
# [0 1 2 3 4 5 6 7]

# %%
print(type(Class))
print(type(features))

Class = Class.values
features = features.values

print(type(Class))
print(type(features))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# split in training 70%, validation 10 %,  test 20% test 
from sklearn.model_selection import train_test_split
# 80 and 20
x_train, x_test, y_train, y_test = train_test_split(features, Class, test_size=0.2, random_state=1)

# %%
# Normalizing data
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)

x_train -= mean
x_train /= std

x_test -= mean
x_test /= std

# %%
# one hot encoding Labels
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# creating a function for plotting

def plot(loss,val_loss,acc,val_acc):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(loss) + 1)

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation acc')
    plt.xlabel('Epochs')
    plt.ylabel('acc')
    plt.legend()
    plt.show()

# %%
from tensorflow.keras import layers, Sequential, optimizers, Input, Model

input_tensor = Input(shape=(8,))
x = layers.Dense(1024, activation='relu')(input_tensor)
y = layers.Dense(512, activation='relu')(x)
z = layers.Dense(256, activation='relu')(y)
z = layers.Dense(128, activation='relu')(z)
z = layers.Dense(64, activation='relu')(z)
z = layers.Dense(32, activation='relu')(z)
z = layers.Dense(128, activation='relu')(y) # acyclic graghs of layers
z = layers.Dense(64, activation='relu')(z)
z = layers.Dense(32, activation='relu')(z)
output_tensor = layers.Dense(8, activation='softmax')(z)

model = Model(input_tensor, output_tensor)

#SGD #RMSprop #Adam #Adadelta #Adagrad ##Adamax ###Nadam #Ftrl
opt = optimizers.Nadam(lr=1e-3)
model.compile(optimizer = opt, 
              loss = "categorical_crossentropy",
              metrics = ["accuracy"])

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              9216
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 610,280
# Trainable params: 610,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
# saving model, creating log for tensorboaed and applying few callbacks

def callbacks(Log,Dir):
  import tensorflow as tf
  import os

  Filepath = Path
  logdir = os.path.join(Filepath, Dir)
  
  callbacks_list = [tf.keras.callbacks.TensorBoard(
                    log_dir=logdir,                 #  tensorboard log path      
                    histogram_freq=1,),
                    tf.keras.callbacks.EarlyStopping(   # stop if not improving
                    monitor='val_accuracy',patience=2,),           # monitor validation accuracy
                    #tf.keras.callbacks.ReduceLROnPlateau(
                    #monitor='val_loss',factor=0.1,         # lr ko .1 se multiply kerdo (kam kerdo)
                    #patience=10,),                # reduce the lrate if val loss stop improving
                    tf.keras.callbacks.ModelCheckpoint(
                    filepath= Filepath,             # save model path
                    monitor='val_loss',             # only save best weights
                    save_best_only=True,)]
  return callbacks_list

# %%
Path = "model1"
Dir = "my_log_dir"   
Call_B_Fun = callbacks(Path,Dir)

batch_size = 512            
epochs = 20                

history = model.fit(x_train, y_train,
                    batch_size=batch_size, epochs = epochs,
                    validation_split = 0.2, callbacks=Call_B_Fun)

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plot(loss,val_loss,acc,val_acc)
# Out:
# Epoch 1/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.9109 - accuracy: 0.6452 - val_loss: 0.8882 - val_accuracy: 0.6484
# Epoch 2/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.8753 - accuracy: 0.6506 - val_loss: 0.8661 - val_accuracy: 0.6513
# Epoch 3/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.8508 - accuracy: 0.6589 - val_loss: 0.8399 - val_accuracy: 0.6640
# Epoch 4/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.8221 - accuracy: 0.6702 - val_loss: 0.8109 - val_accuracy: 0.6755
# Epoch 5/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.7912 - accuracy: 0.6841 - val_loss: 0.7832 - val_accuracy: 0.6882
# Epoch 6/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.7610 - accuracy: 0.6982 - val_loss: 0.7600 - val_accuracy: 0.7005
# Epoch 7/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.7321 - accuracy: 0.7118 - val_loss: 0.7341 - val_accuracy: 0.7126
# Epoch 8/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.7059 - accuracy: 0.7245 - val_loss: 0.7112 - val_accuracy: 0.7250
# Epoch 9/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.6810 - accuracy: 0.7365 - val_loss: 0.6952 - val_accuracy: 0.7332
# Epoch 10/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.6587 - accuracy: 0.7468 - val_loss: 0.6701 - val_accuracy: 0.7453
# Epoch 11/20
# 5298/5298 [==============================] - 22s 4ms/step - loss: 0.6377 - accuracy: 0.7567 - val_loss: 0.6538 - val_accuracy: 0.7543
# Epoch 12/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.6189 - accuracy: 0.7656 - val_loss: 0.6412 - val_accuracy: 0.7591
# Epoch 13/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.6013 - accuracy: 0.7738 - val_loss: 0.6304 - val_accuracy: 0.7646
# Epoch 14/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5852 - accuracy: 0.7812 - val_loss: 0.6069 - val_accuracy: 0.7758
# Epoch 15/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5702 - accuracy: 0.7879 - val_loss: 0.5941 - val_accuracy: 0.7836
# Epoch 16/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5565 - accuracy: 0.7942 - val_loss: 0.5839 - val_accuracy: 0.7878
# Epoch 17/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5429 - accuracy: 0.8000 - val_loss: 0.5750 - val_accuracy: 0.7922
# Epoch 18/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.5316 - accuracy: 0.8050 - val_loss: 0.5629 - val_accuracy: 0.7975
# Epoch 19/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5202 - accuracy: 0.8101 - val_loss: 0.5568 - val_accuracy: 0.8007
# Epoch 20/20
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5095 - accuracy: 0.8146 - val_loss: 0.5498 - val_accuracy: 0.8042

# %%
# saving our model
model.save('model1/emg_1.h5')

# %%
#################

# %%
# loading saved model
from tensorflow.keras.models import load_model
emg = 'model1/emg_1.h5'
emg_model = load_model(emg)
emg_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              9216
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 610,280
# Trainable params: 610,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Removing layers

new_model = Model(emg_model.inputs, emg_model.layers[-2].output) # removing layers
new_model.summary()
# removed all layers except conv
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              9216
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# =================================================================
# Total params: 610,016
# Trainable params: 610,016
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import layers, optimizers, Input, Model

input_tensor = Input(shape=(8,))
x = new_model(input_tensor)       # this is our old model
#z = layers.Dense(256, activation='relu')(x)
output_tensor = layers.Dense(8, activation='softmax')(x)

model = Model(input_tensor, output_tensor)

#SGD #RMSprop #Adam #Adadelta #Adagrad ##Adamax ###Nadam #Ftrl
opt = optimizers.Nadam(lr=1e-3)
model.compile(optimizer = opt, 
              loss = "categorical_crossentropy",
              metrics = ["accuracy"])

model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# functional_3 (Functional)    (None, 32)                610016
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 264
# =================================================================
# Total params: 610,280
# Trainable params: 610,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
def callbacks(Log,Dir):
  import tensorflow as tf
  import os

  Filepath = Path
  logdir = os.path.join(Filepath, Dir)
  
  callbacks_list = [tf.keras.callbacks.TensorBoard(
                    log_dir=logdir,                 #  tensorboard log path      
                    histogram_freq=1,),
                    tf.keras.callbacks.EarlyStopping(   # stop if not improving
                    monitor='val_loss',patience=2,),           # monitor validation loss
                    tf.keras.callbacks.ReduceLROnPlateau(
                    monitor='val_loss',factor=0.1,         # lr ko .1 se multiply kerdo (kam kerdo)
                    patience=10,),                # reduce the lrate if val loss stop improving
                    tf.keras.callbacks.ModelCheckpoint(
                    filepath= Filepath,             # save model path
                    monitor='val_loss',             # only save best weights
                    save_best_only=True,)]
  return callbacks_list

# %%
Path = "model2"
Dir = "my_log_dir"   
Call_B_Fun = callbacks(Path,Dir)

batch_size = 512            
epochs = 30                

history = model.fit(x_train, y_train,
                    batch_size=batch_size, epochs = epochs,
                    validation_split = 0.2, callbacks=Call_B_Fun)

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plot(loss,val_loss,acc,val_acc)
# Out:
# Epoch 1/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.8424 - accuracy: 0.6738 - val_loss: 0.7033 - val_accuracy: 0.7249
# Epoch 2/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.6085 - accuracy: 0.7678 - val_loss: 0.5927 - val_accuracy: 0.7815
# Epoch 3/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5346 - accuracy: 0.8029 - val_loss: 0.5536 - val_accuracy: 0.8022
# Epoch 4/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.5068 - accuracy: 0.8153 - val_loss: 0.5477 - val_accuracy: 0.8054
# Epoch 5/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4907 - accuracy: 0.8225 - val_loss: 0.5293 - val_accuracy: 0.8147
# Epoch 6/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4782 - accuracy: 0.8277 - val_loss: 0.5202 - val_accuracy: 0.8180
# Epoch 7/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4682 - accuracy: 0.8320 - val_loss: 0.5052 - val_accuracy: 0.8257
# Epoch 8/30
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.4587 - accuracy: 0.8362 - val_loss: 0.5052 - val_accuracy: 0.8252
# Epoch 9/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4503 - accuracy: 0.8398 - val_loss: 0.5015 - val_accuracy: 0.8280
# Epoch 10/30
# 5298/5298 [==============================] - 22s 4ms/step - loss: 0.4419 - accuracy: 0.8432 - val_loss: 0.4856 - val_accuracy: 0.8351
# Epoch 11/30
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.4339 - accuracy: 0.8464 - val_loss: 0.4878 - val_accuracy: 0.8345
# Epoch 12/30
# 5298/5298 [==============================] - 22s 4ms/step - loss: 0.4270 - accuracy: 0.8493 - val_loss: 0.4835 - val_accuracy: 0.8361
# Epoch 13/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4201 - accuracy: 0.8523 - val_loss: 0.4666 - val_accuracy: 0.8437
# Epoch 14/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4138 - accuracy: 0.8548 - val_loss: 0.4631 - val_accuracy: 0.8446
# Epoch 15/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4077 - accuracy: 0.8574 - val_loss: 0.4602 - val_accuracy: 0.8459
# Epoch 16/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.4015 - accuracy: 0.8596 - val_loss: 0.4595 - val_accuracy: 0.8464
# Epoch 17/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3957 - accuracy: 0.8618 - val_loss: 0.4518 - val_accuracy: 0.8510
# Epoch 18/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3902 - accuracy: 0.8641 - val_loss: 0.4492 - val_accuracy: 0.8526
# Epoch 19/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3855 - accuracy: 0.8660 - val_loss: 0.4421 - val_accuracy: 0.8558
# Epoch 20/30
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3803 - accuracy: 0.8682 - val_loss: 0.4466 - val_accuracy: 0.8545
# Epoch 21/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3763 - accuracy: 0.8699 - val_loss: 0.4343 - val_accuracy: 0.8587
# Epoch 22/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3709 - accuracy: 0.8721 - val_loss: 0.4322 - val_accuracy: 0.8603
# Epoch 23/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3670 - accuracy: 0.8736 - val_loss: 0.4297 - val_accuracy: 0.8616
# Epoch 24/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3623 - accuracy: 0.8754 - val_loss: 0.4281 - val_accuracy: 0.8619
# Epoch 25/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3581 - accuracy: 0.8771 - val_loss: 0.4231 - val_accuracy: 0.8647
# Epoch 26/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3546 - accuracy: 0.8784 - val_loss: 0.4172 - val_accuracy: 0.8670
# Epoch 27/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3502 - accuracy: 0.8802 - val_loss: 0.4159 - val_accuracy: 0.8680
# Epoch 28/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3469 - accuracy: 0.8815 - val_loss: 0.4088 - val_accuracy: 0.8714
# Epoch 29/30
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3434 - accuracy: 0.8829 - val_loss: 0.4111 - val_accuracy: 0.8696
# Epoch 30/30
# 5298/5298 [==============================] - 21s 4ms/step - loss: 0.3398 - accuracy: 0.8843 - val_loss: 0.4051 - val_accuracy: 0.8739

# %%
# saving our model
model.save('model2/emg_2.h5')

# %%
###################

# %%
# loading saved model
from tensorflow.keras.models import load_model
emg = 'model2/emg_2.h5'
emg_model = load_model(emg)
emg_model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# functional_3 (Functional)    (None, 32)                610016
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 264
# =================================================================
# Total params: 610,280
# Trainable params: 610,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import layers, Sequential, optimizers, Input, Model

input_tensor = Input(shape=(8,))
x = layers.Dense(1024, activation='relu')(input_tensor)
y = layers.Dense(512, activation='relu')(x)
z = layers.Dense(256, activation='relu')(y)
z = layers.Dense(128, activation='relu')(z)
z = layers.Dense(64, activation='relu')(z)
z = layers.Dense(32, activation='relu')(z)
z = layers.Dense(128, activation='relu')(y) # acyclic graghs of layers
z = layers.Dense(64, activation='relu')(z)
z = layers.Dense(32, activation='relu')(z)
output_tensor = layers.Dense(8, activation='softmax')(z)

model = Model(input_tensor, output_tensor)

opt = optimizers.Nadam(lr=1e-3)
model.compile(optimizer = opt, 
              loss = "categorical_crossentropy",
              metrics = ["accuracy"])

model.set_weights(emg_model.get_weights())   # using pretrained model weights

model.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 8)]               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1024)              9216
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 264
# =================================================================
# Total params: 610,280
# Trainable params: 610,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks_list = [tf.keras.callbacks.EarlyStopping(   # stop if not improving
                monitor='acc',patience=5,),           # monitor validation accuracy
                tf.keras.callbacks.ModelCheckpoint(
                filepath='my_model.h5',
                monitor='val_loss',                   # only save best weights
                save_best_only=True,)]                # when vall loss is improved

batch_size = 512           
epochs = 20                

history = model.fit(x_train, y_train,
                    batch_size=batch_size, epochs = epochs,
                    validation_split = 0.2,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3340 - accuracy: 0.8866 - val_loss: 0.4053 - val_accuracy: 0.8746
# Epoch 2/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3305 - accuracy: 0.8882 - val_loss: 0.4055 - val_accuracy: 0.8745
# Epoch 3/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3284 - accuracy: 0.8891 - val_loss: 0.4011 - val_accuracy: 0.8755
# Epoch 4/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3262 - accuracy: 0.8896 - val_loss: 0.3992 - val_accuracy: 0.8765
# Epoch 5/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3237 - accuracy: 0.8906 - val_loss: 0.3925 - val_accuracy: 0.8795
# Epoch 6/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3206 - accuracy: 0.8917 - val_loss: 0.3927 - val_accuracy: 0.8798
# Epoch 7/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3183 - accuracy: 0.8928 - val_loss: 0.3961 - val_accuracy: 0.8784
# Epoch 8/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3150 - accuracy: 0.8941 - val_loss: 0.3897 - val_accuracy: 0.8828
# Epoch 9/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3126 - accuracy: 0.8950 - val_loss: 0.3859 - val_accuracy: 0.8835
# Epoch 10/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3102 - accuracy: 0.8961 - val_loss: 0.3823 - val_accuracy: 0.8850
# Epoch 11/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3073 - accuracy: 0.8971 - val_loss: 0.3810 - val_accuracy: 0.8865
# Epoch 12/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.3050 - accuracy: 0.8978 - val_loss: 0.3842 - val_accuracy: 0.8846
# Epoch 13/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.3027 - accuracy: 0.8987 - val_loss: 0.3859 - val_accuracy: 0.8844
# Epoch 14/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.2998 - accuracy: 0.8997 - val_loss: 0.3832 - val_accuracy: 0.8863
# Epoch 15/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.2982 - accuracy: 0.9005 - val_loss: 0.3826 - val_accuracy: 0.8852
# Epoch 16/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.2959 - accuracy: 0.9015 - val_loss: 0.3731 - val_accuracy: 0.8906
# Epoch 17/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.2937 - accuracy: 0.9024 - val_loss: 0.3749 - val_accuracy: 0.8895
# Epoch 18/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.2912 - accuracy: 0.9031 - val_loss: 0.3725 - val_accuracy: 0.8904
# Epoch 19/20
# 5298/5298 [==============================] - 19s 4ms/step - loss: 0.2892 - accuracy: 0.9040 - val_loss: 0.3767 - val_accuracy: 0.8893
# Epoch 20/20
# 5298/5298 [==============================] - 20s 4ms/step - loss: 0.2876 - accuracy: 0.9046 - val_loss: 0.3765 - val_accuracy: 0.8899

# %%
model.save('emg_3.h5')

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plot(loss,val_loss,acc,val_acc)

# %%
evaluation = model.evaluate(x_test,  y_test,batch_size=batch_size, verbose=2)
print()
print("Test loss :",evaluation[0]*100,"%")
print("Test accuracy :",evaluation[1]*100,"%")
# Out:
# 1656/1656 - 3s - loss: 0.3753 - accuracy: 0.8900
#
# Test loss : 37.53182888031006 %
# Test accuracy : 88.99551630020142 %

# %% [markdown]
# ### Prediction

# %%
predict = 105
a = np.argmax(model.predict(x_test)[predict])
print("Predicted Class: ",a)
print("Actual Class: ",np.argmax(y_test[predict]))
# Out:
# Predicted Class:  7
# Actual Class:  7
